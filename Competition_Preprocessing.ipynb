# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
# LightGBM
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold

# %%
df = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
df.columns
# Out:
# Index(['LOAN_ID', 'ORIGINAL_LANGUAGE', 'DESCRIPTION', 'DESCRIPTION_TRANSLATED',
#        'LOAN_AMOUNT', 'IMAGE_ID', 'ACTIVITY_NAME', 'SECTOR_NAME', 'LOAN_USE',
#        'COUNTRY_CODE', 'COUNTRY_NAME', 'TOWN_NAME', 'CURRENCY_POLICY',
#        'CURRENCY_EXCHANGE_COVERAGE_RATE', 'CURRENCY', 'TAGS',
#        'REPAYMENT_INTERVAL', 'DISTRIBUTION_MODEL'],
#       dtype='object')

# %%
df.head()
# Out:
#    LOAN_ID ORIGINAL_LANGUAGE  \
# 0  1733169           English
# 1  1546998           English
# 2  1808517           Spanish
# 3  1452940           English
# 4  1778420           English
#
#                                          DESCRIPTION  \
# 0  Teodora is a 50-year-old married woman from th...
# 1  Diego is 32 years old and lives in the municip...
# 2  Osman, es un joven de 27 años de edad, soltero...
# 3  His name is Nino, 31 years old, married to Che...
# 4  Pictured above is Teresa, often described as a...
#
#                               DESCRIPTION_TRANSLATED  LOAN_AMOUNT  IMAGE_ID  \
# 0  Teodora is a 50-year-old married woman from th...          100   3115271
# 1  Diego is 32 years old and lives in the municip...         1350   2870403
# 2  Osman is a young man, 27 years old, single, an...          225   3215705
# 3  His name is Nino, 31 years old, married to Che...          350   2745031
# 4  Pictured above is Teresa, often described as a...          625   3083800
#
#           ACTIVITY_NAME     SECTOR_NAME  \
# 0               Weaving            Arts
# 1           Barber Shop        Services
# 2               Farming     Agriculture
# 3  Motorcycle Transport  Transportation
# 4               Farming     Agriculture
#
#                                             LOAN_USE COUNTRY_CODE  \
# 0  to purchase  materials like nipa palm, bamboo ...           PH
# 1  to buy two hair clippers, a new barber chair, ...           CO
# 2  to purchase sacks of fertilizers to care for a...           HN
# 3  to pay for fuel, tires and change oil for his ...           PH
# 4  to purchase hybrid seeds and fertilizer to imp...           KE
#
#   COUNTRY_NAME                       TOWN_NAME CURRENCY_POLICY  \
# 0  Philippines                Maribojoc, Bohol          shared
# 1     Colombia                        Apartadó          shared
# 2     Honduras  Nueva Frontera, Santa Barbara.          shared
# 3  Philippines                  Silang, Cavite          shared
# 4        Kenya                          Mumias          shared
#
#    CURRENCY_EXCHANGE_COVERAGE_RATE CURRENCY  \
# 0                              0.1      PHP
# 1                              0.1      COP
# 2                              0.1      HNL
# 3                              0.1      PHP
# 4                              0.1      KES
#
#                                                 TAGS REPAYMENT_INTERVAL  \
# 0                                           #Elderly            monthly
# 1                       user_favorite, user_favorite            monthly
# 2                                                NaN             bullet
# 3                                      user_favorite            monthly
# 4  #Eco-friendly, #Sustainable Ag, #Parent, #Elde...             bullet
#
#   DISTRIBUTION_MODEL
# 0      field_partner
# 1      field_partner
# 2      field_partner
# 3      field_partner
# 4      field_partner

# %% [markdown]
# ### Description_Translated

# %%
df['DESCRIPTION_TRANSLATED'] = df['DESCRIPTION_TRANSLATED'].fillna('Tursun is 62 years old and she comes from the Yavan district of Tajikistan where she lives with her children and her husband. She is quiet, intelligent, dynamic, and responsible. As someone who is always looking for something new to get involved in, she has decided to start a new business. She is used to working hard and cannot stay at home with nothing to do. Tursun wants to get involved in animal husbandry, an activity which she has learned from one of her neighbors. She is taking this loan to buy a few head of livestock. She is confident that she will succeed. Thanks to the loan that she has requested, she will be able to buy a few head of livestock and to start her new business. With high hopes, Tursun is turning to you for support')

# %%
# Count the number of the translated description
df['count_description_translated'] = df['DESCRIPTION_TRANSLATED'].apply(lambda x: x.split()) 
df['count_description_translated'] = df['count_description_translated'].apply(lambda x: len(x)) 
df.head()
# Out:
#    LOAN_ID ORIGINAL_LANGUAGE  \
# 0  1733169           English
# 1  1546998           English
# 2  1808517           Spanish
# 3  1452940           English
# 4  1778420           English
#
#                                          DESCRIPTION  \
# 0  Teodora is a 50-year-old married woman from th...
# 1  Diego is 32 years old and lives in the municip...
# 2  Osman, es un joven de 27 años de edad, soltero...
# 3  His name is Nino, 31 years old, married to Che...
# 4  Pictured above is Teresa, often described as a...
#
#                               DESCRIPTION_TRANSLATED  LOAN_AMOUNT  IMAGE_ID  \
# 0  Teodora is a 50-year-old married woman from th...          100   3115271
# 1  Diego is 32 years old and lives in the municip...         1350   2870403
# 2  Osman is a young man, 27 years old, single, an...          225   3215705
# 3  His name is Nino, 31 years old, married to Che...          350   2745031
# 4  Pictured above is Teresa, often described as a...          625   3083800
#
#           ACTIVITY_NAME     SECTOR_NAME  \
# 0               Weaving            Arts
# 1           Barber Shop        Services
# 2               Farming     Agriculture
# 3  Motorcycle Transport  Transportation
# 4               Farming     Agriculture
#
#                                             LOAN_USE COUNTRY_CODE  \
# 0  to purchase  materials like nipa palm, bamboo ...           PH
# 1  to buy two hair clippers, a new barber chair, ...           CO
# 2  to purchase sacks of fertilizers to care for a...           HN
# 3  to pay for fuel, tires and change oil for his ...           PH
# 4  to purchase hybrid seeds and fertilizer to imp...           KE
#
#   COUNTRY_NAME                       TOWN_NAME CURRENCY_POLICY  \
# 0  Philippines                Maribojoc, Bohol          shared
# 1     Colombia                        Apartadó          shared
# 2     Honduras  Nueva Frontera, Santa Barbara.          shared
# 3  Philippines                  Silang, Cavite          shared
# 4        Kenya                          Mumias          shared
#
#    CURRENCY_EXCHANGE_COVERAGE_RATE CURRENCY  \
# 0                              0.1      PHP
# 1                              0.1      COP
# 2                              0.1      HNL
# 3                              0.1      PHP
# 4                              0.1      KES
#
#                                                 TAGS REPAYMENT_INTERVAL  \
# 0                                           #Elderly            monthly
# 1                       user_favorite, user_favorite            monthly
# 2                                                NaN             bullet
# 3                                      user_favorite            monthly
# 4  #Eco-friendly, #Sustainable Ag, #Parent, #Elde...             bullet
#
#   DISTRIBUTION_MODEL  count_description_translated
# 0      field_partner                           122
# 1      field_partner                           180
# 2      field_partner                           103
# 3      field_partner                           234
# 4      field_partner                           167

# %% [markdown]
# ## Loan Use

# %%
df['count_LOAN_USE'] = df['LOAN_USE'].apply(lambda x: x.split()) 
df['count_LOAN_USE'] = df['count_LOAN_USE'].apply(lambda x: len(x)) 
df.head()
# Out:
#    LOAN_ID ORIGINAL_LANGUAGE  \
# 0  1733169           English
# 1  1546998           English
# 2  1808517           Spanish
# 3  1452940           English
# 4  1778420           English
#
#                                          DESCRIPTION  \
# 0  Teodora is a 50-year-old married woman from th...
# 1  Diego is 32 years old and lives in the municip...
# 2  Osman, es un joven de 27 años de edad, soltero...
# 3  His name is Nino, 31 years old, married to Che...
# 4  Pictured above is Teresa, often described as a...
#
#                               DESCRIPTION_TRANSLATED  LOAN_AMOUNT  IMAGE_ID  \
# 0  Teodora is a 50-year-old married woman from th...          100   3115271
# 1  Diego is 32 years old and lives in the municip...         1350   2870403
# 2  Osman is a young man, 27 years old, single, an...          225   3215705
# 3  His name is Nino, 31 years old, married to Che...          350   2745031
# 4  Pictured above is Teresa, often described as a...          625   3083800
#
#           ACTIVITY_NAME     SECTOR_NAME  \
# 0               Weaving            Arts
# 1           Barber Shop        Services
# 2               Farming     Agriculture
# 3  Motorcycle Transport  Transportation
# 4               Farming     Agriculture
#
#                                             LOAN_USE COUNTRY_CODE  \
# 0  to purchase  materials like nipa palm, bamboo ...           PH
# 1  to buy two hair clippers, a new barber chair, ...           CO
# 2  to purchase sacks of fertilizers to care for a...           HN
# 3  to pay for fuel, tires and change oil for his ...           PH
# 4  to purchase hybrid seeds and fertilizer to imp...           KE
#
#   COUNTRY_NAME                       TOWN_NAME CURRENCY_POLICY  \
# 0  Philippines                Maribojoc, Bohol          shared
# 1     Colombia                        Apartadó          shared
# 2     Honduras  Nueva Frontera, Santa Barbara.          shared
# 3  Philippines                  Silang, Cavite          shared
# 4        Kenya                          Mumias          shared
#
#    CURRENCY_EXCHANGE_COVERAGE_RATE CURRENCY  \
# 0                              0.1      PHP
# 1                              0.1      COP
# 2                              0.1      HNL
# 3                              0.1      PHP
# 4                              0.1      KES
#
#                                                 TAGS REPAYMENT_INTERVAL  \
# 0                                           #Elderly            monthly
# 1                       user_favorite, user_favorite            monthly
# 2                                                NaN             bullet
# 3                                      user_favorite            monthly
# 4  #Eco-friendly, #Sustainable Ag, #Parent, #Elde...             bullet
#
#   DISTRIBUTION_MODEL  count_description_translated  count_LOAN_USE
# 0      field_partner                           122              12
# 1      field_partner                           180              16
# 2      field_partner                           103              12
# 3      field_partner                           234              11
# 4      field_partner                           167              11

# %%
train_columns = ["ORIGINAL_LANGUAGE", "ACTIVITY_NAME", "SECTOR_NAME", "COUNTRY_CODE","CURRENCY_POLICY",
       "CURRENCY","REPAYMENT_INTERVAL", "DISTRIBUTION_MODEL",'Cu']

target = "LOAN_AMOUNT"

X = df[train_columns]
y = df[target]

# %%
for column in X.columns:
    le = LabelEncoder()
    target_column = X[column]
    le.fit(target_column)
    label_encoded_column = le.transform(target_column)
    X[column] = pd.Series(label_encoded_column).astype("category")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
numerical = df[['count_description_translated', 'count_LOAN_USE']]

# %%
train = pd.concat([X, numerical], axis=1)

# %%
train
# Out:
#       ORIGINAL_LANGUAGE ACTIVITY_NAME SECTOR_NAME COUNTRY_CODE  \
# 0                     0           157           1           39
# 1                     0             9          12            7
# 2                     4            57           0           16
# 3                     0            97          13           39
# 4                     0            57           0           22
# ...                 ...           ...         ...          ...
# 91328                 4           120           0           10
# 91329                 0           110           8           39
# 91330                 0            72           6           24
# 91331                 4            57           0            7
# 91332                 0            47           4           55
#
#       CURRENCY_POLICY CURRENCY REPAYMENT_INTERVAL DISTRIBUTION_MODEL  \
# 0                   0       34                  2                  1
# 1                   0        4                  2                  1
# 2                   0       13                  0                  1
# 3                   0       34                  2                  1
# 4                   0       19                  0                  1
# ...               ...      ...                ...                ...
# 91328               0       45                  2                  1
# 91329               1       34                  2                  1
# 91330               0       45                  2                  1
# 91331               0        4                  2                  1
# 91332               0       44                  1                  1
#
#        count_description_translated  count_LOAN_USE
# 0                               122              12
# 1                               180              16
# 2                               103              12
# 3                               234              11
# 4                               167              11
# ...                             ...             ...
# 91328                           198               7
# 91329                            65               8
# 91330                           104              11
# 91331                           154              19
# 91332                           200              13
#
# [91333 rows x 10 columns]

# %%
train.to_csv('after_processing.csv',index=False)
y.to_csv('y.csv',index=False)
